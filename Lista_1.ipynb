# %% [markdown]
# <a href="https://colab.research.google.com/github/mreginal/mreginal/blob/main/Lista_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1

# %%
valor = float(input("Qual o valor da gasolina? "))
encher = float(input('Em dinheiro, quanto deseja colocar? '))
v = encher / valor
print ('O total é de ', v, 'litros.')

# %% [markdown]
# 2

# %%
km1 = float (input('KM inicial:'))
km2 = float (input('KM final: '))
gaso = float (input('Litros gastos: '))
kml = (km2 - km1) / gaso 
print('O resultado é de ', kml, 'km/l')

# %% [markdown]
# 3

# %%
c_in = float (input('Qual era o valor original de sua dívida? '))
d_a = float (input('Quantos dias estão atrasados?'))
p_jur = float (input('Valor da multa diária: '))
total = c_in + (d_a * p_jur)
print('O valor atual é de: ', total, 'reais.')

# %% [markdown]
# 4

# %%
print ('Primeiro cômodo')
l1 = float (input('Largura: '))
c1 = float (input('Comprimento: '))
print ('Segundo cômodo')
l2 = float (input('Largura: '))
c2= float (input('Comprimento:'))
print ('Terceiro cômodo')
l3 = float (input('Largura: '))
c3 = float (input('Comprimento: '))
print('Quarto cômodo')
l4 = float (input('Largura: '))
c4 = float (input('Comprimento: '))
total = (l1*c1) + (l2*c2) + (l3*c3) + (l4*c4)
print('TOTAL:', total, 'm².')

# %% [markdown]
# 5

# %%
dolar= float (input('Qual a cotação atual do dolar? '))
real = float (input('Quanto deseja converter?'))
total= real / dolar
print(f'O total é de {total:.2f} dólares.')

# %% [markdown]
# 6

# %%
sal_a = float (input('Salário atual: '))
percentual = float (input('Porcentagem de aumento: '))
juros = sal_a*percentual/100
total = sal_a + juros
print(f'O seu novo salário é de {total} reais.')

# %% [markdown]
# 7

# %%
sal_men = float (input('Qual o seu sálario mensal? '))
cust = float (input('Qual o valor de suas contas?'))
sobra= sal_men - cust
a1= sobra * 12
milao = 1000000 / a1
print(f' O tempo que irá levar para ser um milionário é de {milao:.1f} anos.')

# %% [markdown]
# 8

# %%
n = int (input('Digite um número: '))
a1 = n - 1
a2 = n - 2
s1 = n + 1
s2 = n + 2
print( a2, a1, n, s1, s2)

# %% [markdown]
# 9

# %%
nome = input('Qual o seu nome? ')
ano_nasc = int (input('Em que ano você nasceu? '))
ano_at= int (input('Em que ano nós estamos? '))
idade = ano_at - ano_nasc 
print(f'{nome} tem {idade} anos.')

# %% [markdown]
# 10

# %%
cS = float (input('Comprimento da sala: '))
lS = float (input('Largura da sala: '))
cC = float (input('Comprimento da carteira: '))
lC = float (input('Largura da carteira: '))
f= (lS + 0.5) / (lC + 0.5)
li= (cS - 1.5 + 0.2 ) / ( cC + 0.2)
cad = int (f+li)
print (f'Cabem {cad} cadeiras nesta sala de aula.')
